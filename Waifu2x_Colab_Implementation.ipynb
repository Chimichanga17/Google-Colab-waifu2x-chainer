# %% [markdown]
# <a href="https://colab.research.google.com/github/mphirke/waifu2x-chainer/blob/master/Waifu2x_Colab_Implementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q cupy-cuda101
# !pip install -q futures
# !pip install -q chainer
# Out:
#      |████████████████████████████████| 409.8MB 52kB/s
# ...

# %%
# !git clone -l -s https://github.com/tsurumeso/waifu2x-chainer.git waifu2x-chainer
# %cd waifu2x-chainer
# Out:
# Cloning into 'waifu2x-chainer'...
# ...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 1449 (delta 0), reused 0 (delta 0), pack-reused 1446
# Receiving objects: 100% (1449/1449), 185.55 MiB | 35.36 MiB/s, done.
# Resolving deltas: 100% (813/813), done.
# /content/waifu2x-chainer

# %%
import google.colab.files
# %cd /content
# %mkdir Input_images
# %mkdir Output_images
# %cd /content/Input_images
uploaded = google.colab.files.upload()
print(uploaded)
# Out:
# /content
# mkdir: cannot create directory ‘Input_images’: File exists
# mkdir: cannot create directory ‘Output_images’: File exists
# /content/Input_images
#      <input type="file" id="files-3039c98d-07a2-453d-8b5a-e9d697234973" name="files[]" multiple disabled />
#      <output id="result-3039c98d-07a2-453d-8b5a-e9d697234973">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ScccRage.JPG to ScccRage.JPG
# Saving ScccSumail.jpg to ScccSumail.jpg
# Saving ScccThinking.jpg to ScccThinking.jpg
# ...

# %%
# %cd /content/waifu2x-chainer
# %pwd
# !python waifu2x.py -m scale -i /content/Input_images -o /content/Output_images -s 2 -a 0 -n 1
# Out:
# /content
# /content/waifu2x-chainer
# 2.0x upscaling... tcmalloc: large alloc 1246003200 bytes == 0x23f96000 @  0x7fc9dce7a1e7 0x7fc9da983ca1 0x7fc9da9e8778 0x7fc9da9874a1 0x53edb5 0x57ec0c 0x4f88ba 0x4fa6c0 0x4f6128 0x4f7d60 0x4f876d 0x4fa6c0 0x4f7a28 0x4f876d 0x4f98c7 0x4f7a28 0x4f876d 0x4f98c7 0x4f7a28 0x4f876d 0x4f98c7 0x4f6128 0x4f7d60 0x4f876d 0x4f98c7 0x4f6128 0x4f7d60 0x4f876d 0x4fa6c0 0x4f4065 0x5a1481
# tcmalloc: large alloc 1246003200 bytes == 0x6e3de000 @  0x7fc9dce7a1e7 0x7fc9da983ca1 0x7fc9da9eb580 0x7fc9da9e05c5 0x7fc9daaad2b0 0x7fc9daa786f7 0x4f8925 0x4f98c7 0x4f6128 0x4f7d60 0x4f876d 0x4f98c7 0x4f7a28 0x4f876d 0x4f98c7 0x4f7a28 0x4f876d 0x4f98c7 0x4f7a28 0x4f876d 0x4f98c7 0x4f6128 0x4f7d60 0x4f876d 0x4f98c7 0x4f6128 0x4f7d60 0x4f876d 0x4fa6c0 0x4f4065 0x5a1481
# OK
# Elapsed time: 59.829605 sec
# Saved as '/content/Output_images/ScccThinking.jpg'
# 2.0x upscaling... OK
# Elapsed time: 76.361507 sec
# Saved as '/content/Output_images/ScccSumail.jpg'
# ...

# %%
# !nvcc --version
# !pip install cupy-cuda100

# %%
# !zip -r /content/output.zip /content/Output_images
# Out:
#   adding: content/Output_images/ (stored 0%)
#   adding: content/Output_images/ScccThinking.jpg (deflated 1%)
#   adding: content/Output_images/ScccSumail.jpg (deflated 0%)
#   adding: content/Output_images/ScccRage.JPG (deflated 1%)
